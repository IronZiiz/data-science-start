# %% [markdown]
# <a href="https://colab.research.google.com/github/IronZiiz/data-science-start/blob/main/A_proj_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read a df
pd.read_csv('/content/drive/MyDrive/Alura/Analise-de-notas-filmes/ml-latest-small/ratings.csv')
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas = pd.read_csv('/content/drive/MyDrive/Alura/Analise-de-notas-filmes/ml-latest-small/ratings.csv')

# %%
notas.shape # Return shape
# Out:
# (100836, 4)

# %%
notas.columns # Return the name of columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
notas.columns= ['usuárioId','filmeID', 'nota', 'registro']

# %%
notas
# Out:
#         usuárioId  filmeID  nota    registro
# 0               1        1   4.0   964982703
# 1               1        3   4.0   964981247
# 2               1        6   4.0   964982224
# 3               1       47   5.0   964983815
# 4               1       50   5.0   964982931
# ...           ...      ...   ...         ...
# 100831        610   166534   4.0  1493848402
# 100832        610   168248   5.0  1493850091
# 100833        610   168250   5.0  1494273047
# 100834        610   168252   5.0  1493846352
# 100835        610   170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.head() # Return the first n rows
# Out:
#    usuárioId  filmeID  nota   registro
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas.iloc[:,2]# Accessing the column and displaying it using the index
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas["nota"].unique() # Return unique values of Series object
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas["nota"].value_counts() # Return a Series containing counts of unique values
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
notas["nota"].value_counts(normalize=4)
# Out:
# nota
# 4.0    0.265957
# 3.0    0.198808
# 5.0    0.131015
# 3.5    0.130271
# 4.5    0.084801
# 2.0    0.074884
# 2.5    0.055040
# 1.0    0.027877
# 1.5    0.017762
# 0.5    0.013586
# Name: proportion, dtype: float64

# %%
notas["nota"].mean() # Mean of values
# Out:
# 3.501556983616962

# %%
notas["nota"].plot(kind = 'hist') # Plot a histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas['nota'].describe() #Generate descriptive statistics
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
sns.boxplot(notas['nota']) # Plot a boxplot
# Out:
# <Axes: ylabel='nota'>

# %%
filmes = pd.read_csv('/content/drive/MyDrive/Alura/Analise-de-notas-filmes/ml-latest-small/movies.csv')

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.columns = ['filmeId', 'titulo', 'genero']
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuárioId  filmeID  nota   registro
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.query('filmeID == 1').mean() # It doesnt make any sense. Because a looking for the nota
# Out:
# usuárioId    3.065302e+02
# filmeID      1.000000e+00
# nota         3.920930e+00
# registro     1.129835e+09
# dtype: float64

# %%
notas.query('filmeID == 1')['nota'].mean() # the mean about the filme with ID = 1
# Out:
# 3.9209302325581397

# %%
medias_por_filme = notas.groupby('filmeID')['nota'].mean()

# %%
medias_por_filme.head()
# Out:
# filmeID
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filme)
# Out:
# <Axes: ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.displot(medias_por_filme, kde = True )
plt.title('Distribuição das médias dos filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das médias dos filmes')
